# %% [markdown]
# <a href="https://colab.research.google.com/github/seyyedRezaRazavi/faceDetection_opencv/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 0- ketabkhane opencv ra nasb mikonim

# %%
pip install opencv-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# 1- aval ketabkhone opencv ra add mikonim

# %%
import cv2
from google.colab.patches import cv2_imshow

# %% [markdown]
# 2- tasvir ra ba ketabkhane cv2 load mikonim

# %%
img = cv2.imread('d2.jpg')

#be siyah o sefid tabdil mikonim
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray)
# Out:
# <PIL.Image.Image image mode=L size=800x800 at 0x7F689AF87DD0>

# %% [markdown]
# 3- model az pish amozeshdade shode baraye tashkhish sorat ra load mikonim

# %%
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

#ejraye model roye tasvir
faces = face_cascade.detectMultiScale(gray, 1.1, 4)

# %% [markdown]
# 4-  sorat haye peyda shode ra dakhele loop mindazim va be tasvire asli noghate tashkhis dade shode ra box rasm mikonim

# %%
for (x, y, w, h) in faces:
    cv2.rectangle(img, (x, y), (x+w, y+h), (255, 0, 0), 2)

# %% [markdown]
# 5- tasvire nahayi ra namayesh midahim

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=800x800 at 0x7F689C7FDFD0>
